# %%
#plotting a  simple line graph
import matplotlib.pyplot as plt
data = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(data)
plt.show()

# %% [markdown]
# ## matplotlib
# > -matplotlib uses a subclass pyplot<br>
# > -fig (figure) and ax (axis) are tupples returned by the plt.subplots(). <br>fig is used if you want to change figure level and also to save as an image <br>
# fig.savefig('name')<br>
# > -plot function simply draw a line from point to point <br>
# -plt.show() is a function that starts a loop, that looks for currect active figure, thus opening one or more <br>
# windows to display them

# %%
#changing label types and line thickness
import matplotlib.pyplot as plt
data = [1,4,9,16,25]
fig, ax = plt.subplots()
ax.plot(data)
ax.set_title('first data visualization', fontsize = 24)
ax.set_xlabel('values', fontsize = 14)
ax.set_ylabel('squire of the values', fontsize=14)
ax.tick_params(axis ='both', labelsize = 14, colors = 'b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - axis(ax) uses set.... class with the labels (X,Y) and aslo title to set text on top and both sides<br>
#     this function string and fontsize arguments<br>
#     ax.set_xlabel('xlabel', fontsize = 14)<br>
# - tick_params is used to change the appeaarance of ticks, ticks labels and gridelines
#     - tick are the values used to show specific points in a cordinate

# %%
#correcting the plot
import matplotlib.pyplot as plt
input_values = [1,2,3,4,5]
data = [1,4,9,16,25]
fig, ax = plt.subplots()
ax.plot(input_values, data)
ax.set_title('first data visualixation', fontsize = 24)
ax.set_xlabel('values', fontsize= 14)
ax.set_ylabel('squre of the values',fontsize = 14)
ax.tick_params(axis = 'both', labelsize = 14)
plt.show

# %%
#using build-in styles
plt.style.available

import matplotlib.pyplot as plt
input_values = [1,2,3,4,5]
data = [1,4,9,16,25]
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(input_values, data)
ax.set_title('first data visualixation', fontsize = 24)
ax.set_xlabel('values', fontsize= 14)
ax.set_ylabel('squre of the values',fontsize = 14)
ax.tick_params(axis = 'both', labelsize = 14)
plt.show

# %% [markdown]
# - implementing a syle using build in subclass style
#     - plt.style.use('seaborn')

# %%
#plottig and stagging a single point usinng scatter
import matplotlib.pyplot as plt
input_values = [1,2,3,4,5]
data = [1,4,9,16,25]
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(input_values, data)
ax.set_title('first data visualixation', fontsize = 24)
ax.set_xlabel('values', fontsize= 14)
ax.set_ylabel('squre of the values',fontsize = 14)
ax.tick_params(axis = 'both', labelsize = 14)
plt.scatter(2,10, s=100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - on the other hand scatter draws single a point defined by the values of x and y axis and assigned size<br>
#        - plt.scatter(5,10, s =30)

# %%
#plottig and stagging a multiple points usinng scatter
import matplotlib.pyplot as plt
input_values = [1,2,3,4,5]
data = [1,4,9,16,25]
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(input_values, data)
ax.set_title('first data visualixation', fontsize = 24)
ax.set_xlabel('values', fontsize= 14)
ax.set_ylabel('squre of the values',fontsize = 14)
ax.tick_params(axis = 'both', labelsize = 14)
plt.scatter(input_values, data, s=20)

# %% [markdown]
# - with scatter you can pass a two list defining x and y axis. thus, drawing multiple points

# %%
#culculating the data automatically
import matplotlib.pyplot as plt
x_axis = range(1,1001)
y_axis = [x**2 for x in x_axis ]
plt.style.use('seaborn')
fig,ax = plt.subplots()
ax.plot(x_axis, y_axis)
ax.set_title('first data visualixation', fontsize = 24)
ax.set_xlabel('values', fontsize = 14)
ax.set_ylabel('squire', fontsize = 14)
ax.tick_params(axis = 'both', labelsize = 14)
plt.scatter(x_axis, y_axis, s = 20)
ax.axis([0,1001, 0, 1100000])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - Axis.axis() functions offerece a convinience way to set axis properties <br>
#     -ax.axis([0,1001, 0, 1100000])<br>
#     -axis([xmin, xmax, ymin, ymax])

# %%
#difining custom colors
import matplotlib.pyplot as plt

x_axis = range(1 ,1001)
y_axis  = [x ** 2 for x in x_axis]
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)
ax.set_title('first data visualization', fontsize=24)
ax.set_xlabel('values', fontsize=14)
ax.set_ylabel('squire of the values', fontsize=14)
ax.tick_params(axis= 'both', labelsize=14)
ax.scatter(x_axis, y_axis, c = 'red', s = 10)
ax.axis([1, 1001, 1, 1100000])
# Out:
# (1.0, 1001.0, 1.0, 1100000.0)

# %%
#ussing color map
import matplotlib.pyplot as plt
x_axis = range(1,1001)
y_axis = [x**2 for x in x_axis]
plt.style.use('seaborn')
fig ,ax = plt.subplots()
ax.plot(x_axis, y_axis)
ax.set_title('data visualization color map', fontsize = 24)
ax.set_xlabel('values', fontsize=14)
ax.set_ylabel('ssquire of the values', fontsize=14)
ax.tick_params(axis='both', labelsize=14)
ax.scatter(x_axis, y_axis, c= y_axis,cmap = plt.cm.Purples , s=10)
ax.axis([1,1001, 1,1100000])
plt.show()

# %%
#random walk project
from random import choice
import matplotlib.pyplot as plt

class random_walk:
    def __init__(self, steps_num = 5000):
        self.steps_num = steps_num
        self.x_values = [0]
        self.y_values = [0]
        
    def walk(self):
        while len(self.x_values)< self.steps_num:
            x_direction = choice([1,-1])
            x_distance = choice([0,1,2,3,4])
            x_step = x_direction * x_distance

            y_direction = choice([1,-1])
            y_distance = choice([0,1,2,3,4])
            y_step = y_direction * y_distance
            
            if self.x_values and self.y_values == 0:
                continue
                
            x = self.x_values[-1] + x_step
            y =self.y_values[-1] + y_step
            
            self.x_values.append(x)
            self.y_values.append(y)
while True:
    rw = random_walk()
    rw.walk()
    plt.style.use('classic')
    fig, ax = plt.subplots()
    ax.plot()
    point_number = range(rw.steps_num)
    ax.scatter(rw.x_values, rw.y_values, c = point_number, cmap = plt.cm.Blues, edgecolors= 'none', s = 15)
    plt.show()
    keep_running = input('would you like to make another walk? (N/Y)')
    if keep_running == 'N':
        break
# Out:
# would you like to make another walk? (N/Y)n
# would you like to make another walk? (N/Y)N

# %%
#rolling dice
from plotly.graph_objs import Bar, Layout
from plotly import offline
from random import randint
class die:
    def __init__(self, sides = 6):
        self.sides = sides
    
    def roll(self):
        return randint(1, self.sides)
    
    
die_class = die()

results = []
for roll_num in range(1000):
    result = die_class.roll()
    results.append(result)

frequencies = []
for values in range(1, die_class.sides+1):
    frequency = results.count(values)
    frequencies.append(frequency)

x_values = list(range(1, die_class.sides))
data = [Bar(x=x_values, y = frequencies)]
x_axis_config = {'title': 'values/sides of a die'}
y_axis_config = {'title': 'results after rolling the die'}
my_layout = Layout(title = 'rolling a die', xaxis = x_axis_config, yaxis = y_axis_config)
offline.plot({'data':data, 'layout':my_layout}, filename = 'd6.html')
# Out:
# 'd6.html'

# %%
#rolling two dice
from random import randint
from plotly.graph_objs import Layout, Bar
from plotly import offline

class die:
    def __init__(self, sides = 6):
        self.sides = sides
    
    
    def roll(self):
        return randint(1, self.sides)

die = die()

results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)
    
frequencies = []
for values in range(1, die.sides+1):
    frequency = results.count(values)
    frequencies.append(frequency)

x_values = list(range(1, die.sides))
data = [Bar(x = x_values, y = frequencies)]
x_axis_config = {'title':'dice sides'}
y_axis_config = {'title': 'frequencies'}
my_layout = Layout(title = 'frequency of a dice', xaxis = x_axis_config, yaxis = y_axis_config)
offline.plot({'data':data, 'layout': my_layout}, filename = 'd6.html')
# Out:
# 'd6.html'
